# %%
from datasets import load_dataset
from collections import Counter

ds = load_dataset("openlifescienceai/medmcqa", split="train")
counts = Counter(ds["subject_name"])
for subject, count in sorted(counts.items(), key=lambda x: -x[1]):
    print(f"{count:>6}  {subject}")
# Out:
#  17887  Medicine
#  16862  Surgery
#  14884  Pathology
#  14560  Anatomy
#  13758  Pharmacology
#  11882  Social & Preventive Medicine
#  11314  Microbiology
#  10013  Gynaecology & Obstetrics
#   8938  Dental
#   8830  Physiology
#   8282  Biochemistry
#   8037  Pediatrics
#   6932  Ophthalmology
#   5900  Forensic Medicine
#   4919  ENT
#   4442  Psychiatry
#   4395  Radiology
#   3172  Anaesthesia
#   3045  Unknown
#   2999  Orthopaedics
#   1771  Skin
